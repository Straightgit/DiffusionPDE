# %%
import scipy
import matplotlib.pyplot as plt
import numpy as np 
mat = scipy.io.loadmat('darcy_results.mat')

# %%
a = mat['a'][0,0,:,:]
u = mat['u'][0,0,:,:]

# %%
plt.imshow(np.array(a))

# %%
plt.imshow(np.array(u))

# %% [markdown]
# ### Misc/Trash

# %%
# len(data[0:198]) + len(data[198:2*198]) + len(data[2*198:3*198]) + len(data[3*198:4*198]) + len(data[4*198:5*198])
# with open('pressur_unstruct_1.pickle', 'wb') as file:
#     # Serialize and save the object to the file
#     pickle.dump(data_1, file)
# with open('pressur_unstruct_2.pickle', 'wb') as file:
#     # Serialize and save the object to the file
#     pickle.dump(data_2, file)
# with open('pressur_unstruct_3.pickle', 'wb') as file:
#     # Serialize and save the object to the file
#     pickle.dump(data_3, file)
# with open('pressur_unstruct_4.pickle', 'wb') as file:
#     # Serialize and save the object to the file
#     pickle.dump(data_4, file)
# with open('pressur_unstruct_5.pickle', 'wb') as file:
#     # Serialize and save the object to the file
#     pickle.dump(data_5, file)

# %%
# with open(r'pressur_unstruct_1.pickle', 'rb') as file:
#     data_test_1 = pickle.load(file)
# with open(r'pressur_unstruct_2.pickle', 'rb') as file:
#     data_test_2 = pickle.load(file)
